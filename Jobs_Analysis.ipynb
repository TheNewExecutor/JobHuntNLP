# %% [markdown]
# # Job Aggregator

# %% [markdown]
# 1. [Motivation](#motivation)
# 2. [Approach](#approach)
# 3. [Gathering the Job Links](#joblinks)
# 4. [Web Scraping](#scraping)
# 5. [Analysis of Jobs Data](#analysis)
#     5.1 [Useful Functions](#functions)
#     5.2 [Jobs by Sector and Size](#sector_size)
#     5.3 [Analysis of Job Descriptions](#job_descriptions)
#     5.4 [Term Frequency - Inverse Document Frequency](#tfidf)
#     5.5 [Extracting Top Key Words from a Job Description](#keywords)

# %% [markdown]
# # How to Use this Notebook
#
# Sections 1-4 are to get the data. If you already have your data saved in a CSV format, skip to section 5 and make sure to load it.

# %% [markdown]
# <a id='motivation'></a>

# %% [markdown]
# ## 1. Motivation

# %% [markdown]
#  - Anyone who has been on a modern job hunt has probably wondered and worried about the central question:
#
#  **what are companies looking for in candidates?**
#
#
#  - Job boards have descriptions that describe the requirements and preferred skills companies seek based on specific positions.
#
#
#  - Reading each description is useful for knowing what specific jobs require, but a **statistical** view of these descriptions would help provide a valuable perspective. What key words appear most frequently, and specifically, what skills are in greatest demand?
#
#
#
#  - This information would empower students, career advisors, and job seekers to cater to the job market.

# %% [markdown]
# <a id='approach'></a>

# %% [markdown]
# ## 2. Approach

# %% [markdown]
# Reading each description one by one and keeping track of statistics like word counts is infeasible when the scale becomes too large. This is where computational resources like `Python` really shine.
#
# We'll need to perform a search in job boards site like Glassdoor and LinkedIn and then save job descriptions and company information. To perform this [webscraping](https://en.wikipedia.org/wiki/Web_scraping), we'll make use of libraries like `scrapy` and `Selenium` to crawl through the various job description subpages and interact with them to get all the information.
#
# There are two tasks needed to get our data:
#
#
# 1. Get a list of job links to feed `scrapy`
#
#
# 2. Use `scrapy` to get what we need from each site.
#
#
# Where does `Selenium` come in? Websites sometimes run javascript which changes content based on user actions. This is the case of a *dynamic* website. `Seleneium` automates browser actions and can navigate the cases of complicated websites.

# %% [markdown]
# <a id='joblinks'></a>

# %% [markdown]
# ## 3. Gathering the Job Links

# %% [markdown]
# Here you can input your own Glassdoor account login information and customize the job title to search for as well as the list of cities to search in. It's worth noting that to prevent duplicate jobs, the cities should be spread out for lowest overlap. Adjusting the number of cities will affect the time it takes to aggregate all the job links.

# %%
import time
from selenium import webdriver
from job_scraping_functions import GlassdoorDriver, LinkedInDriver
import pickle

# %%
# Choose file names to save the links under

base_name = ''
job_links_glassdoor =  base_name + '_search_glassdoor.pickle'
job_links_linkedin = base_name + '_search_linkedin.pickle'

output_job_data_glassdoor = base_name+'_glassdoor.csv'
output_job_data_linkedin = base_name+'_linkedin.csv'



# Put in any valid login account for Glassdoor
username = ''
password = ''

# Replace with the job title you wish to search for
job = 'Operations Manager'

# Place cities as they appear in Glassdoor, in the format City, state initials
locations_ = ['Davis, CA', 'San Francisco, CA', 'San Jose, CA', 'Los Angeles, CA',
             'San Diego, CA', 'Irvine, CA', 'Portland, OR', 'Houston, TX',
             'Austin, TX', 'Charlotte, NC','Raleigh, NC', 'Nashville, TN',
             'Miami, FL', 'Tampa, FL', 'Orland, FL', 'Washington, DC',
             'Arlington, VA','Boston, MA', 'New York, NY']

# Choose a subset of the above locations, or even new ones you've tried on Glassdoor

locations = ['San Francisco, CA', 'San Jose, CA']

# %%
driver_glassdoor = GlassdoorDriver()
# We save the links in a dictionary and write that to a disk with a filename we choose
glassdoor_start = time.time()
job_dict_glassdoor = driver_glassdoor.full_search_results(username, password, job, locations)
glassdoor_end = time.time()
# Out:
# Problem with page 29
# Problem with page 29

# %%
driver_linkedin = LinkedInDriver()
linkedin_start = time.time()
job_dict_linkedin = driver_linkedin.full_search_results(job, locations, delay=2)
linkedin_end = time.time()

# %%
job_dict_linkedin
# Out:
# {'San Francisco, CA': ['https://www.linkedin.com/jobs/view/operations-manager-at-stockwell-1453535656?refId=6384f27b-263a-4e2d-8a40-e61caa33a0e8&position=1&pageNum=0&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/senior-creative-operations-manager-at-planet-interactive-1483161817?refId=6384f27b-263a-4e2d-8a40-e61caa33a0e8&position=2&pageNum=0&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-paradigm-1490886996?refId=6384f27b-263a-4e2d-8a40-e61caa33a0e8&position=3&pageNum=0&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-dark-heart-nursery-1477492496?refId=6384f27b-263a-4e2d-8a40-e61caa33a0e8&position=4&pageNum=0&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-g4s-1461198131?refId=6384f27b-263a-4e2d-8a40-e61caa33a0e8&position=5&pageNum=0&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-amerisourcebergen-1434817514?refId=6384f27b-263a-4e2d-8a40-e61caa33a0e8&position=6&pageNum=0&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-shipt-1438073947?refId=6384f27b-263a-4e2d-8a40-e61caa33a0e8&position=7&pageNum=0&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-%F0%9F%A5%81-at-snackpass-1476541284?refId=6384f27b-263a-4e2d-8a40-e61caa33a0e8&position=8&pageNum=0&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-hyatt-hotels-corporation-1464955075?refId=6384f27b-263a-4e2d-8a40-e61caa33a0e8&position=9&pageNum=0&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-darkstore-1405506182?refId=6384f27b-263a-4e2d-8a40-e61caa33a0e8&position=10&pageNum=0&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-robert-half-1493133703?refId=6384f27b-263a-4e2d-8a40-e61caa33a0e8&position=11&pageNum=0&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-san-francisco-international-airport-1286002761?refId=6384f27b-263a-4e2d-8a40-e61caa33a0e8&position=12&pageNum=0&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-true-north-1254685386?refId=6384f27b-263a-4e2d-8a40-e61caa33a0e8&position=13&pageNum=0&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-oto-development-1334394024?refId=6384f27b-263a-4e2d-8a40-e61caa33a0e8&position=14&pageNum=0&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-firefly-wenatchee-1510692012?refId=6384f27b-263a-4e2d-8a40-e61caa33a0e8&position=15&pageNum=0&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-cypress-creek-renewables-1480005048?refId=6384f27b-263a-4e2d-8a40-e61caa33a0e8&position=16&pageNum=0&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-new-markets-at-instawork-1497240536?refId=6384f27b-263a-4e2d-8a40-e61caa33a0e8&position=17&pageNum=0&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-galanter-jones-1511930155?refId=6384f27b-263a-4e2d-8a40-e61caa33a0e8&position=18&pageNum=0&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-ts-1509225446?refId=6384f27b-263a-4e2d-8a40-e61caa33a0e8&position=19&pageNum=0&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-ripleys-believe-it-or-not-1278425243?refId=6384f27b-263a-4e2d-8a40-e61caa33a0e8&position=20&pageNum=0&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-rollins-inc-1155416517?refId=6384f27b-263a-4e2d-8a40-e61caa33a0e8&position=21&pageNum=0&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-stockwell-1508199947?refId=6384f27b-263a-4e2d-8a40-e61caa33a0e8&position=22&pageNum=0&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-able-services-1433721131?refId=6384f27b-263a-4e2d-8a40-e61caa33a0e8&position=23&pageNum=0&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/community-operations-manager-at-picsart-inc-1480975443?refId=6384f27b-263a-4e2d-8a40-e61caa33a0e8&position=24&pageNum=0&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/senior-operations-manager-at-forward-1430519702?refId=6384f27b-263a-4e2d-8a40-e61caa33a0e8&position=25&pageNum=0&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-pacific-dental-services-1404134429?refId=aaaddc21-1bea-4b63-bc5c-8734645ffc2d&position=1&pageNum=1&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-walmart-1420723159?refId=aaaddc21-1bea-4b63-bc5c-8734645ffc2d&position=2&pageNum=1&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/senior-compliance-operations-manager-at-exelixis-1358393521?refId=aaaddc21-1bea-4b63-bc5c-8734645ffc2d&position=3&pageNum=1&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-card-1511338385?refId=aaaddc21-1bea-4b63-bc5c-8734645ffc2d&position=4&pageNum=1&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-compass-1449916850?refId=aaaddc21-1bea-4b63-bc5c-8734645ffc2d&position=5&pageNum=1&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-paradigm-management-services-llc-1511134583?refId=aaaddc21-1bea-4b63-bc5c-8734645ffc2d&position=6&pageNum=1&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-cvs-health-1510902927?refId=aaaddc21-1bea-4b63-bc5c-8734645ffc2d&position=7&pageNum=1&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/clinic-operations-manager-at-healthright-360-1333623862?refId=aaaddc21-1bea-4b63-bc5c-8734645ffc2d&position=8&pageNum=1&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-hogarth-worldwide-1483708695?refId=aaaddc21-1bea-4b63-bc5c-8734645ffc2d&position=9&pageNum=1&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-talentburst-an-inc-5000-company-1483708269?refId=aaaddc21-1bea-4b63-bc5c-8734645ffc2d&position=10&pageNum=1&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-lark-health-1455637246?refId=aaaddc21-1bea-4b63-bc5c-8734645ffc2d&position=11&pageNum=1&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/support-operations-manager-at-asana-1481729889?refId=aaaddc21-1bea-4b63-bc5c-8734645ffc2d&position=12&pageNum=1&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-cort-1485259067?refId=aaaddc21-1bea-4b63-bc5c-8734645ffc2d&position=13&pageNum=1&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/project-operations-manager-at-adyen-1485245842?refId=aaaddc21-1bea-4b63-bc5c-8734645ffc2d&position=14&pageNum=1&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-platinum-advisors-llc-1485236484?refId=aaaddc21-1bea-4b63-bc5c-8734645ffc2d&position=15&pageNum=1&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-rubedo-life-sciences-1491584884?refId=aaaddc21-1bea-4b63-bc5c-8734645ffc2d&position=16&pageNum=1&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-instacart-1307368264?refId=aaaddc21-1bea-4b63-bc5c-8734645ffc2d&position=17&pageNum=1&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/digital-operations-manager-at-aquent-1504278973?refId=aaaddc21-1bea-4b63-bc5c-8734645ffc2d&position=18&pageNum=1&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-snappr-inc-1391667043?refId=aaaddc21-1bea-4b63-bc5c-8734645ffc2d&position=19&pageNum=1&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/content-operations-manager-at-electronic-arts-ea-1485299458?refId=aaaddc21-1bea-4b63-bc5c-8734645ffc2d&position=20&pageNum=1&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/finance-operations-manager-global-support-operations-at-doordash-1483114585?refId=aaaddc21-1bea-4b63-bc5c-8734645ffc2d&position=21&pageNum=1&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/analytics-operations-manager-at-impossible-foods-1483797552?refId=aaaddc21-1bea-4b63-bc5c-8734645ffc2d&position=22&pageNum=1&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/manager-operations-at-walmart-ecommerce-1485200720?refId=aaaddc21-1bea-4b63-bc5c-8734645ffc2d&position=23&pageNum=1&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/community-operations-manager-for-headquarters-by-wework-at-wework-1457634920?refId=aaaddc21-1bea-4b63-bc5c-8734645ffc2d&position=24&pageNum=1&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/senior-business-operations-manager-at-intuit-1481707474?refId=aaaddc21-1bea-4b63-bc5c-8734645ffc2d&position=25&pageNum=1&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/cloud-platforms-and-operations-manager-at-dropbox-1448813769?refId=f4049f8e-c8d1-4f7c-ba47-add13b06e252&position=1&pageNum=2&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/senior-operations-manager-at-swing-education-1470609316?refId=f4049f8e-c8d1-4f7c-ba47-add13b06e252&position=2&pageNum=2&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/hr-operations-manager-at-feedzai-1511427157?refId=f4049f8e-c8d1-4f7c-ba47-add13b06e252&position=3&pageNum=2&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-veterans-initiative-1508351831?refId=f4049f8e-c8d1-4f7c-ba47-add13b06e252&position=4&pageNum=2&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-astranis-1508520432?refId=f4049f8e-c8d1-4f7c-ba47-add13b06e252&position=5&pageNum=2&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-informed-k12-1511772297?refId=f4049f8e-c8d1-4f7c-ba47-add13b06e252&position=6&pageNum=2&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/senior-operations-manager-at-skyslope-1507967705?refId=f4049f8e-c8d1-4f7c-ba47-add13b06e252&position=7&pageNum=2&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-customer-support-at-lime-1413799926?refId=f4049f8e-c8d1-4f7c-ba47-add13b06e252&position=8&pageNum=2&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-mv-transportation-1502751218?refId=f4049f8e-c8d1-4f7c-ba47-add13b06e252&position=9&pageNum=2&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/ad-operations-manager-at-quizlet-1405574481?refId=f4049f8e-c8d1-4f7c-ba47-add13b06e252&position=10&pageNum=2&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-agro-merchants-group-1498221321?refId=f4049f8e-c8d1-4f7c-ba47-add13b06e252&position=11&pageNum=2&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/sr-partnership-operations-manager-at-cbs-interactive-1398112551?refId=f4049f8e-c8d1-4f7c-ba47-add13b06e252&position=12&pageNum=2&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/business-operations-manager-at-particle-1491323165?refId=f4049f8e-c8d1-4f7c-ba47-add13b06e252&position=13&pageNum=2&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-richmond-ca-at-gotcha-1307642467?refId=f4049f8e-c8d1-4f7c-ba47-add13b06e252&position=14&pageNum=2&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-anaergia-inc-1502574660?refId=f4049f8e-c8d1-4f7c-ba47-add13b06e252&position=15&pageNum=2&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/sales-operations-manager-at-luma-health-1479822093?refId=f4049f8e-c8d1-4f7c-ba47-add13b06e252&position=16&pageNum=2&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/people-operations-manager-at-vicarious-ai-1479460793?refId=f4049f8e-c8d1-4f7c-ba47-add13b06e252&position=17&pageNum=2&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-laz-parking-1486836608?refId=f4049f8e-c8d1-4f7c-ba47-add13b06e252&position=18&pageNum=2&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-patrol-alarm-systems-ltd-1459074307?refId=f4049f8e-c8d1-4f7c-ba47-add13b06e252&position=19&pageNum=2&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-comfort-keepers-1473015369?refId=f4049f8e-c8d1-4f7c-ba47-add13b06e252&position=20&pageNum=2&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-alliedbarton-security-services-1510911264?refId=f4049f8e-c8d1-4f7c-ba47-add13b06e252&position=21&pageNum=2&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/people-operations-manager-at-babylist-1487488981?refId=f4049f8e-c8d1-4f7c-ba47-add13b06e252&position=22&pageNum=2&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/business-operations-manager-at-homelight-1362614885?refId=f4049f8e-c8d1-4f7c-ba47-add13b06e252&position=23&pageNum=2&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/business-operations-manager-at-near-protocol-1394453962?refId=f4049f8e-c8d1-4f7c-ba47-add13b06e252&position=24&pageNum=2&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/facilities-operations-manager-at-eden-1419295986?refId=f4049f8e-c8d1-4f7c-ba47-add13b06e252&position=25&pageNum=2&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/sales-operations-manager-at-better-place-forests-1481753526?refId=7b1c05ee-32aa-4d2f-a907-77c3ebe8cbdf&position=1&pageNum=3&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-property-management-at-tenderloin-housing-clinic-1448145457?refId=7b1c05ee-32aa-4d2f-a907-77c3ebe8cbdf&position=2&pageNum=3&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/partner-operations-manager-at-mixbook-1347310325?refId=7b1c05ee-32aa-4d2f-a907-77c3ebe8cbdf&position=3&pageNum=3&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-west-marine-1483109650?refId=7b1c05ee-32aa-4d2f-a907-77c3ebe8cbdf&position=4&pageNum=3&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/people-operations-manager-at-airtable-1463431413?refId=7b1c05ee-32aa-4d2f-a907-77c3ebe8cbdf&position=5&pageNum=3&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-wedriveu-1486824056?refId=7b1c05ee-32aa-4d2f-a907-77c3ebe8cbdf&position=6&pageNum=3&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-pr-hacker-1496274945?refId=7b1c05ee-32aa-4d2f-a907-77c3ebe8cbdf&position=7&pageNum=3&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/creative-operations-manager-at-shutterfly-inc-1483118154?refId=7b1c05ee-32aa-4d2f-a907-77c3ebe8cbdf&position=8&pageNum=3&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/customer-success-operations-manager-at-branch-1483185905?refId=7b1c05ee-32aa-4d2f-a907-77c3ebe8cbdf&position=9&pageNum=3&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/partner-operations-manager-at-quest-groups-llc-1445126748?refId=7b1c05ee-32aa-4d2f-a907-77c3ebe8cbdf&position=10&pageNum=3&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/business-operations-manager-retail-innovation-at-shopkick-1485228988?refId=7b1c05ee-32aa-4d2f-a907-77c3ebe8cbdf&position=11&pageNum=3&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/logistics-operations-manager-at-native-1453536298?refId=7b1c05ee-32aa-4d2f-a907-77c3ebe8cbdf&position=12&pageNum=3&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/hospitality-operations-manager-at-ten-lifestyle-group-1448525374?refId=7b1c05ee-32aa-4d2f-a907-77c3ebe8cbdf&position=13&pageNum=3&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/assistant-operations-manager-at-arco-s-self-storage-1448825126?refId=7b1c05ee-32aa-4d2f-a907-77c3ebe8cbdf&position=14&pageNum=3&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/people-operations-manager-at-entangled-group-1483718419?refId=7b1c05ee-32aa-4d2f-a907-77c3ebe8cbdf&position=15&pageNum=3&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/engineering-operations-manager-at-alation-1483790541?refId=7b1c05ee-32aa-4d2f-a907-77c3ebe8cbdf&position=16&pageNum=3&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/sustainability-operations-manager-at-alexandria-real-estate-equities-inc-1454449707?refId=7b1c05ee-32aa-4d2f-a907-77c3ebe8cbdf&position=17&pageNum=3&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-integration-manager-at-cruise-1477185570?refId=7b1c05ee-32aa-4d2f-a907-77c3ebe8cbdf&position=18&pageNum=3&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/workplace-operations-manager-at-plaid-1468977906?refId=7b1c05ee-32aa-4d2f-a907-77c3ebe8cbdf&position=19&pageNum=3&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-payments-at-airbnb-1355582276?refId=7b1c05ee-32aa-4d2f-a907-77c3ebe8cbdf&position=20&pageNum=3&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/revenue-operations-manager-at-coupa-software-1485263248?refId=7b1c05ee-32aa-4d2f-a907-77c3ebe8cbdf&position=21&pageNum=3&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/visual-operations-manager-at-talbots-1512706056?refId=7b1c05ee-32aa-4d2f-a907-77c3ebe8cbdf&position=22&pageNum=3&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/sr-operations-manager-at-amazon-1399769249?refId=7b1c05ee-32aa-4d2f-a907-77c3ebe8cbdf&position=23&pageNum=3&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/user-support-operations-manager-at-shopstyle-1465162494?refId=7b1c05ee-32aa-4d2f-a907-77c3ebe8cbdf&position=24&pageNum=3&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/senior-business-operations-manager-at-tradeshift-1483775856?refId=7b1c05ee-32aa-4d2f-a907-77c3ebe8cbdf&position=25&pageNum=3&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/talent-acquisition-operations-manager-lead-at-sysdig-1454428387?refId=f775b16c-ce12-44fe-83ac-1a53b3c0be52&position=1&pageNum=4&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/information-security-operations-manager-at-betterup-1414698161?refId=f775b16c-ce12-44fe-83ac-1a53b3c0be52&position=2&pageNum=4&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/biosample-operations-manager-bom-at-bayside-solutions-1446168505?refId=f775b16c-ce12-44fe-83ac-1a53b3c0be52&position=3&pageNum=4&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-program-manager-at-sequoia-consulting-group-1452509716?refId=f775b16c-ce12-44fe-83ac-1a53b3c0be52&position=4&pageNum=4&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/happiness-manager-operations-manager-at-oh-my-green-1363947408?refId=f775b16c-ce12-44fe-83ac-1a53b3c0be52&position=5&pageNum=4&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/people-operations-manager-at-fleetsmith-1476015106?refId=f775b16c-ce12-44fe-83ac-1a53b3c0be52&position=6&pageNum=4&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/people-operations-manager-at-forge-formerly-equidate-1457542491?refId=f775b16c-ce12-44fe-83ac-1a53b3c0be52&position=7&pageNum=4&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-coretechs-direct-1487857748?refId=f775b16c-ce12-44fe-83ac-1a53b3c0be52&position=8&pageNum=4&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/associate-product-operations-manager-at-juniper-square-1465430308?refId=f775b16c-ce12-44fe-83ac-1a53b3c0be52&position=9&pageNum=4&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/manager-operations-at-jll-1411445824?refId=f775b16c-ce12-44fe-83ac-1a53b3c0be52&position=10&pageNum=4&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/creative-operations-manager-events-and-experiences-at-google-1459457583?refId=f775b16c-ce12-44fe-83ac-1a53b3c0be52&position=11&pageNum=4&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-woodward-inc-1459395168?refId=f775b16c-ce12-44fe-83ac-1a53b3c0be52&position=12&pageNum=4&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-ii-station-at-fedex-ground-1481784414?refId=f775b16c-ce12-44fe-83ac-1a53b3c0be52&position=13&pageNum=4&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/central-operations-manager-at-spin-1514286245?refId=f775b16c-ce12-44fe-83ac-1a53b3c0be52&position=14&pageNum=4&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/sales-operations-manager-at-lq-digital-1375580113?refId=f775b16c-ce12-44fe-83ac-1a53b3c0be52&position=15&pageNum=4&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/sr-partnership-strategy-and-operations-manager-at-twitter-1490094161?refId=f775b16c-ce12-44fe-83ac-1a53b3c0be52&position=16&pageNum=4&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/sales-operations-manager-at-benchling-1369830633?refId=f775b16c-ce12-44fe-83ac-1a53b3c0be52&position=17&pageNum=4&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/service-operations-manager-at-otis-elevator-co-1408513300?refId=f775b16c-ce12-44fe-83ac-1a53b3c0be52&position=18&pageNum=4&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/machine-learning-operations-manager-at-labelbox-1422312833?refId=f775b16c-ce12-44fe-83ac-1a53b3c0be52&position=19&pageNum=4&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-expa-1478616981?refId=f775b16c-ce12-44fe-83ac-1a53b3c0be52&position=20&pageNum=4&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/central-operations-manager-at-spin-electric-scooter-sharing-1508127695?refId=f775b16c-ce12-44fe-83ac-1a53b3c0be52&position=21&pageNum=4&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/product-operations-manager-at-ike-1405501499?refId=f775b16c-ce12-44fe-83ac-1a53b3c0be52&position=22&pageNum=4&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/sales-operations-manager-at-blend-1483760889?refId=f775b16c-ce12-44fe-83ac-1a53b3c0be52&position=23&pageNum=4&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-project-manager-at-modsy-1461689465?refId=f775b16c-ce12-44fe-83ac-1a53b3c0be52&position=24&pageNum=4&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/business-operations-manager-at-allscripts-1459515347?refId=f775b16c-ce12-44fe-83ac-1a53b3c0be52&position=25&pageNum=4&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/website-operations-manager-at-renew-financial-1478578082?refId=886d9428-e963-42dc-9a53-e8293748d0d7&position=1&pageNum=5&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/construction-operations-manager-at-matrix-hg-inc-matrix-1483744443?refId=886d9428-e963-42dc-9a53-e8293748d0d7&position=2&pageNum=5&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/live-operations-manager-lion-studios-at-applovin-1483745904?refId=886d9428-e963-42dc-9a53-e8293748d0d7&position=3&pageNum=5&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/sales-operations-manager-at-area-1-security-1405372662?refId=886d9428-e963-42dc-9a53-e8293748d0d7&position=4&pageNum=5&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/manufacturing-operations-manager-at-nexkey-inc-1459100272?refId=886d9428-e963-42dc-9a53-e8293748d0d7&position=5&pageNum=5&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/distribution-center-operations-manager-ca0016753827-at-rexel-usa-1463511748?refId=886d9428-e963-42dc-9a53-e8293748d0d7&position=6&pageNum=5&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-inflight-catering-at-dnata-1451810111?refId=886d9428-e963-42dc-9a53-e8293748d0d7&position=7&pageNum=5&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/customer-operations-manager-at-upstart-1370207332?refId=886d9428-e963-42dc-9a53-e8293748d0d7&position=8&pageNum=5&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-ii-at-fremont-bank-1483115878?refId=886d9428-e963-42dc-9a53-e8293748d0d7&position=9&pageNum=5&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/program-manager-operations-at-verily-life-sciences-1373322628?refId=886d9428-e963-42dc-9a53-e8293748d0d7&position=10&pageNum=5&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/senior-revenue-operations-manager-at-wepay-1405389650?refId=886d9428-e963-42dc-9a53-e8293748d0d7&position=11&pageNum=5&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/product-operations-manager-at-keeptruckin-1390566127?refId=886d9428-e963-42dc-9a53-e8293748d0d7&position=12&pageNum=5&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-r2c-1405501795?refId=886d9428-e963-42dc-9a53-e8293748d0d7&position=13&pageNum=5&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/product-operations-manager-at-thumbtack-1446175951?refId=886d9428-e963-42dc-9a53-e8293748d0d7&position=14&pageNum=5&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/facilities-and-operations-manager-at-eden-1509953979?refId=886d9428-e963-42dc-9a53-e8293748d0d7&position=15&pageNum=5&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/business-operations-manager-at-carta-1465132382?refId=886d9428-e963-42dc-9a53-e8293748d0d7&position=16&pageNum=5&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/sr-operations-program-manager-at-density-inc-1459945082?refId=886d9428-e963-42dc-9a53-e8293748d0d7&position=17&pageNum=5&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/global-operations-manager-at-picnichealth-1449523941?refId=886d9428-e963-42dc-9a53-e8293748d0d7&position=18&pageNum=5&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-project-manager-at-salesforce-1437194304?refId=886d9428-e963-42dc-9a53-e8293748d0d7&position=19&pageNum=5&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/sales-operations-manager-at-scoop-technologies-inc-1452374028?refId=886d9428-e963-42dc-9a53-e8293748d0d7&position=20&pageNum=5&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/sr-operations-manager-customer-support-head-of-americas-at-coinbase-1485205701?refId=886d9428-e963-42dc-9a53-e8293748d0d7&position=21&pageNum=5&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/sales-operations-manager-at-plastiq-1463176560?refId=886d9428-e963-42dc-9a53-e8293748d0d7&position=22&pageNum=5&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/product-manager-operations-at-alto-pharmacy-1481743654?refId=886d9428-e963-42dc-9a53-e8293748d0d7&position=23&pageNum=5&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/logistics-inventory-operations-manager-at-because-1485209209?refId=886d9428-e963-42dc-9a53-e8293748d0d7&position=24&pageNum=5&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/sales-operations-manager-at-okta-inc-1459443167?refId=886d9428-e963-42dc-9a53-e8293748d0d7&position=25&pageNum=5&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/people-operations-manager-at-godfrey-dadich-partners-1413760078?refId=99593f0e-d14c-4001-8797-8a09ead75e9f&position=1&pageNum=6&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/central-operations-manager-product-connection-jump-at-uber-1454429133?refId=99593f0e-d14c-4001-8797-8a09ead75e9f&position=2&pageNum=6&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/sales-operations-manager-global-planning-and-reporting-at-intercom-1455631856?refId=99593f0e-d14c-4001-8797-8a09ead75e9f&position=3&pageNum=6&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-zimory-1386751567?refId=99593f0e-d14c-4001-8797-8a09ead75e9f&position=4&pageNum=6&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/compliance-and-operations-manager-at-bbva-in-the-usa-1506641992?refId=99593f0e-d14c-4001-8797-8a09ead75e9f&position=5&pageNum=6&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/regional-operations-manager-at-pace-supply-corp-1480639525?refId=99593f0e-d14c-4001-8797-8a09ead75e9f&position=6&pageNum=6&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-the-regency-ballroom-at-aeg-1463138793?refId=99593f0e-d14c-4001-8797-8a09ead75e9f&position=7&pageNum=6&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-assistant-manager-at-vitagene-1472974771?refId=99593f0e-d14c-4001-8797-8a09ead75e9f&position=8&pageNum=6&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/people-operations-manager-at-omada-health-1434867203?refId=99593f0e-d14c-4001-8797-8a09ead75e9f&position=9&pageNum=6&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-support-manager-at-blue-apron-1327603836?refId=99593f0e-d14c-4001-8797-8a09ead75e9f&position=10&pageNum=6&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/business-operations-manager-at-wanderjaunt-1399395477?refId=99593f0e-d14c-4001-8797-8a09ead75e9f&position=11&pageNum=6&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/peoplesoft-operations-manager-at-university-of-california-office-of-the-president-1448823338?refId=99593f0e-d14c-4001-8797-8a09ead75e9f&position=12&pageNum=6&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-oakland-at-alchemy-legal-1508727474?refId=99593f0e-d14c-4001-8797-8a09ead75e9f&position=13&pageNum=6&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/sales-strategy-operations-manager-at-velvetjobs-1432811003?refId=99593f0e-d14c-4001-8797-8a09ead75e9f&position=14&pageNum=6&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/product-manager-operations-at-coalition-co-1291432854?refId=99593f0e-d14c-4001-8797-8a09ead75e9f&position=15&pageNum=6&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/socal-distribution-operations-manager-at-bloom-farms%E2%84%A2-1450818234?refId=99593f0e-d14c-4001-8797-8a09ead75e9f&position=16&pageNum=6&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/pricing-operations-manager-at-getaround-1481785872?refId=99593f0e-d14c-4001-8797-8a09ead75e9f&position=17&pageNum=6&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/sales-operations-strategy-manager-at-front-1446523262?refId=99593f0e-d14c-4001-8797-8a09ead75e9f&position=18&pageNum=6&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/manager-business-operations-at-glassdoor-1356539789?refId=99593f0e-d14c-4001-8797-8a09ead75e9f&position=19&pageNum=6&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-program-manager-at-auris-health-inc-1421436916?refId=99593f0e-d14c-4001-8797-8a09ead75e9f&position=20&pageNum=6&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/sales-operations-manager-at-premise-data-1486272793?refId=99593f0e-d14c-4001-8797-8a09ead75e9f&position=21&pageNum=6&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/senior-operations-manager-at-got-it-inc-1510488055?refId=99593f0e-d14c-4001-8797-8a09ead75e9f&position=22&pageNum=6&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/sales-operations-manager-at-udemy-1487270631?refId=99593f0e-d14c-4001-8797-8a09ead75e9f&position=23&pageNum=6&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/sales-operations-manager-at-zendesk-1444293208?refId=99593f0e-d14c-4001-8797-8a09ead75e9f&position=24&pageNum=6&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/people-operations-manager-at-komodo-health-1445175450?refId=99593f0e-d14c-4001-8797-8a09ead75e9f&position=25&pageNum=6&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/marketing-operations-project-manager-at-crawford-group-1468968200?refId=48fef5d0-dda1-4f56-811d-59b67e75078f&position=1&pageNum=7&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/accounting-operations-manager-at-elder-care-alliance-1465163627?refId=48fef5d0-dda1-4f56-811d-59b67e75078f&position=2&pageNum=7&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/grid-operations-manager-at-pwc-1332773310?refId=48fef5d0-dda1-4f56-811d-59b67e75078f&position=3&pageNum=7&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/business-operations-manager-at-postmates-inc-1397974382?refId=48fef5d0-dda1-4f56-811d-59b67e75078f&position=4&pageNum=7&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/business-operations-manager-at-genesys-1423663375?refId=48fef5d0-dda1-4f56-811d-59b67e75078f&position=5&pageNum=7&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/business-operations-manager-at-hearsay-systems-1355508600?refId=48fef5d0-dda1-4f56-811d-59b67e75078f&position=6&pageNum=7&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/chatbot-operations-manager-senior-leader-at-wells-fargo-1496148565?refId=48fef5d0-dda1-4f56-811d-59b67e75078f&position=7&pageNum=7&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/client-implementation-and-operations-manager-at-spire-health-1486234220?refId=48fef5d0-dda1-4f56-811d-59b67e75078f&position=8&pageNum=7&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/biomarker-operations-project-manager-%E2%80%93-at-integrated-resources-inc-iri-1477128190?refId=48fef5d0-dda1-4f56-811d-59b67e75078f&position=9&pageNum=7&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/sales-operations-manager-at-comfy-1345231715?refId=48fef5d0-dda1-4f56-811d-59b67e75078f&position=10&pageNum=7&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/business-operations-strategy-manager-at-lendingclub-1481731228?refId=48fef5d0-dda1-4f56-811d-59b67e75078f&position=11&pageNum=7&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-labor-manager-at-jobsinlogistics-com-1504795679?refId=48fef5d0-dda1-4f56-811d-59b67e75078f&position=12&pageNum=7&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/sr-business-operations-manager-at-twitch-1439671450?refId=48fef5d0-dda1-4f56-811d-59b67e75078f&position=13&pageNum=7&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/museum-store-warehouse-operations-manager-at-sfmoma-san-francisco-museum-of-modern-art-1483728008?refId=48fef5d0-dda1-4f56-811d-59b67e75078f&position=14&pageNum=7&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/manager-tech-operations-at-elastic-1449540121?refId=48fef5d0-dda1-4f56-811d-59b67e75078f&position=15&pageNum=7&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/sales-operations-manager-at-agari-1394601851?refId=48fef5d0-dda1-4f56-811d-59b67e75078f&position=16&pageNum=7&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/network-engineering-operations-manager-at-verizon-1508133745?refId=48fef5d0-dda1-4f56-811d-59b67e75078f&position=17&pageNum=7&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/plant-operations-manager-at-america-s-best-beverage-1440723971?refId=48fef5d0-dda1-4f56-811d-59b67e75078f&position=18&pageNum=7&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/retail-operations-senior-manager-at-sephora-1463114383?refId=48fef5d0-dda1-4f56-811d-59b67e75078f&position=19&pageNum=7&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/legal-operations-manager-knowledge-management-trainer-at-gilead-sciences-1447617765?refId=48fef5d0-dda1-4f56-811d-59b67e75078f&position=20&pageNum=7&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/district-operations-manager-at-wsp-usa-1485766081?refId=48fef5d0-dda1-4f56-811d-59b67e75078f&position=21&pageNum=7&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/office-operations-manager-at-groove-co-1273301043?refId=48fef5d0-dda1-4f56-811d-59b67e75078f&position=22&pageNum=7&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/research-and-development-operations-manager-at-grifols-1445192845?refId=48fef5d0-dda1-4f56-811d-59b67e75078f&position=23&pageNum=7&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/assistant-operations-manager-overnight-at-motivate-llc-1451526559?refId=48fef5d0-dda1-4f56-811d-59b67e75078f&position=24&pageNum=7&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/business-operations-performance-systems-manager-at-lyft-1445171886?refId=48fef5d0-dda1-4f56-811d-59b67e75078f&position=25&pageNum=7&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/data-operations-manager-at-clarify-health-solutions-1376512213?refId=0c467fb5-4747-4672-85c2-56ccaf9f9bb2&position=1&pageNum=8&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/marketing-operations-program-manager-at-new-relic-inc-1465190979?refId=0c467fb5-4747-4672-85c2-56ccaf9f9bb2&position=2&pageNum=8&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-biomarkers-biosamples-at-alector-1339346367?refId=0c467fb5-4747-4672-85c2-56ccaf9f9bb2&position=3&pageNum=8&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/strategy-and-operations-program-manager-at-yoh-a-day-zimmermann-company-1445061136?refId=0c467fb5-4747-4672-85c2-56ccaf9f9bb2&position=4&pageNum=8&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/senior-operations-manager-at-sbm-1496299631?refId=0c467fb5-4747-4672-85c2-56ccaf9f9bb2&position=5&pageNum=8&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-at-allied-universal-1284608674?refId=0c467fb5-4747-4672-85c2-56ccaf9f9bb2&position=6&pageNum=8&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/sales-operations-pricing-manager-at-full-harvest-1407089280?refId=0c467fb5-4747-4672-85c2-56ccaf9f9bb2&position=7&pageNum=8&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/sales-operations-manager-at-exabeam-1486224450?refId=0c467fb5-4747-4672-85c2-56ccaf9f9bb2&position=8&pageNum=8&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-project-manager-at-bpm-llp-1284049477?refId=0c467fb5-4747-4672-85c2-56ccaf9f9bb2&position=9&pageNum=8&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-assistant-manager-at-dollar-tree-stores-1513023644?refId=0c467fb5-4747-4672-85c2-56ccaf9f9bb2&position=10&pageNum=8&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/technical-operations-manager-at-lisnr-1510057523?refId=0c467fb5-4747-4672-85c2-56ccaf9f9bb2&position=11&pageNum=8&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/design-operations-project-manager-brand-marketing-at-rally-health-1485278259?refId=0c467fb5-4747-4672-85c2-56ccaf9f9bb2&position=12&pageNum=8&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/sales-operations-strategy-manager-at-front-1508566674?refId=0c467fb5-4747-4672-85c2-56ccaf9f9bb2&position=13&pageNum=8&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-assistant-manager-at-dollar-tree-1510064646?refId=0c467fb5-4747-4672-85c2-56ccaf9f9bb2&position=14&pageNum=8&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/sales-operations-manager-at-modern-health-1356525153?refId=0c467fb5-4747-4672-85c2-56ccaf9f9bb2&position=15&pageNum=8&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/hr-people-operations-manager-at-aquabyte-1430642824?refId=0c467fb5-4747-4672-85c2-56ccaf9f9bb2&position=16&pageNum=8&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/regional-operations-manager-at-guaranteed-rate-1352400668?refId=0c467fb5-4747-4672-85c2-56ccaf9f9bb2&position=17&pageNum=8&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/hr-operations-specialist-manager-at-baidu-inc-1467267691?refId=0c467fb5-4747-4672-85c2-56ccaf9f9bb2&position=18&pageNum=8&trk=guest_job_search_job-result-card_result-card_full-click',
# ...
#   'https://www.linkedin.com/jobs/view/office-manager-at-clearstory-data-1508887299?refId=8ff7cedf-9451-4cad-a378-1d44373be8d5&position=6&pageNum=37&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/program-manager-at-amick-brown-cloud-technologies-sap-and-business-intelligence-consulting-1505030384?refId=8ff7cedf-9451-4cad-a378-1d44373be8d5&position=7&pageNum=37&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/jr-events-operation-manager-at-synergis-1437139394?refId=8ff7cedf-9451-4cad-a378-1d44373be8d5&position=8&pageNum=37&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/clinic-manager-at-hca-healthcare-1446136004?refId=8ff7cedf-9451-4cad-a378-1d44373be8d5&position=9&pageNum=37&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/facilities-and-asset-management-manager-at-slac-national-accelerator-laboratory-1472382871?refId=8ff7cedf-9451-4cad-a378-1d44373be8d5&position=10&pageNum=37&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/business-line-manager-at-caliva-1506431232?refId=8ff7cedf-9451-4cad-a378-1d44373be8d5&position=11&pageNum=37&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/sr-project-manager-system-integration-at-thermo-fisher-scientific-1507583683?refId=8ff7cedf-9451-4cad-a378-1d44373be8d5&position=12&pageNum=37&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/senior-technical-program-manager-at-walmart-1437091715?refId=8ff7cedf-9451-4cad-a378-1d44373be8d5&position=13&pageNum=37&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/contract-finance-manager-at-branch-1485236613?refId=8ff7cedf-9451-4cad-a378-1d44373be8d5&position=14&pageNum=37&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/sr-manager-internal-audit-at-bloom-energy-1436996276?refId=8ff7cedf-9451-4cad-a378-1d44373be8d5&position=15&pageNum=37&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/digital-marketing-program-manager-at-motion-recruitment-partners-1503321039?refId=8ff7cedf-9451-4cad-a378-1d44373be8d5&position=16&pageNum=37&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/sales-enablement-communications-senior-manager-at-equinix-1449506856?refId=8ff7cedf-9451-4cad-a378-1d44373be8d5&position=17&pageNum=37&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/executive-assistant-executive-leader-support-at-hp-1493941298?refId=8ff7cedf-9451-4cad-a378-1d44373be8d5&position=18&pageNum=37&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/it-inventory-and-procurement-manager-at-lucid-motors-1444271027?refId=8ff7cedf-9451-4cad-a378-1d44373be8d5&position=19&pageNum=37&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/people-operations-business-partner-ii-at-argo-ai-1467470208?refId=8ff7cedf-9451-4cad-a378-1d44373be8d5&position=20&pageNum=37&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/commodity-manager-152464-at-lumileds-1449149061?refId=8ff7cedf-9451-4cad-a378-1d44373be8d5&position=21&pageNum=37&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/director-of-product-marketing-ammk508-at-fortinet-1496213783?refId=8ff7cedf-9451-4cad-a378-1d44373be8d5&position=22&pageNum=37&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/program-manager-sales-data-governance-at-rubrik-inc-1408459231?refId=8ff7cedf-9451-4cad-a378-1d44373be8d5&position=23&pageNum=37&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/customer-care-product-manager-walmart-ecommerce-at-walmart-ecommerce-1459178979?refId=8ff7cedf-9451-4cad-a378-1d44373be8d5&position=24&pageNum=37&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/recruiting-global-processes-program-manager-at-apex-systems-1508970051?refId=8ff7cedf-9451-4cad-a378-1d44373be8d5&position=25&pageNum=37&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/special-operations-specialist-silicon-valley-at-lyft-1305981223?refId=5367e09e-1bc6-48fe-962b-392fea47158c&position=1&pageNum=38&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/executive-director-of-care-management-at-clinical-management-consultants-1486175957?refId=5367e09e-1bc6-48fe-962b-392fea47158c&position=2&pageNum=38&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/manager-it-vmo-at-pharmacyclics-an-abbvie-company-1496144647?refId=5367e09e-1bc6-48fe-962b-392fea47158c&position=3&pageNum=38&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/global-security-operations-manager-at-xilinx-1481702081?refId=5367e09e-1bc6-48fe-962b-392fea47158c&position=4&pageNum=38&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/assistant-manager-at-gas-stations-1407341806?refId=5367e09e-1bc6-48fe-962b-392fea47158c&position=5&pageNum=38&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/key-account-manager-at-schneider-electric-1306102534?refId=5367e09e-1bc6-48fe-962b-392fea47158c&position=6&pageNum=38&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/volunteer-associate-clinical-operations-manager-for-immigration-hardship-center-at-volunteermatch-1459957399?refId=5367e09e-1bc6-48fe-962b-392fea47158c&position=7&pageNum=38&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/accounting-manager-at-nelson-companies-1486267194?refId=5367e09e-1bc6-48fe-962b-392fea47158c&position=8&pageNum=38&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/sr-community-manager-at-essex-property-trust-1484520394?refId=5367e09e-1bc6-48fe-962b-392fea47158c&position=9&pageNum=38&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/assistant-yard-manager-equipment-coordinator-at-k-d-landscaping-1511059825?refId=5367e09e-1bc6-48fe-962b-392fea47158c&position=10&pageNum=38&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/product-manager-advanced-media-platform-mountain-view-at-frequence-1502706965?refId=5367e09e-1bc6-48fe-962b-392fea47158c&position=11&pageNum=38&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-manager-fire-at-darbs-red-hawk-fire-security-1513980321?refId=5367e09e-1bc6-48fe-962b-392fea47158c&position=12&pageNum=38&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/it-project-manager-infrastructure-mergers-acquisitions-at-trianz-1486684524?refId=5367e09e-1bc6-48fe-962b-392fea47158c&position=13&pageNum=38&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/strategy-and-operations-manager-industry-partnerships-at-coursera-1514136041?refId=5367e09e-1bc6-48fe-962b-392fea47158c&position=14&pageNum=38&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/housekeeping-manager-at-hersha-hospitality-management-1491911644?refId=5367e09e-1bc6-48fe-962b-392fea47158c&position=15&pageNum=38&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/restaurant-general-manager-at-taco-bell-1500729051?refId=5367e09e-1bc6-48fe-962b-392fea47158c&position=16&pageNum=38&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/sr-anomaly-detection-product-manager-at-box-1455638336?refId=5367e09e-1bc6-48fe-962b-392fea47158c&position=17&pageNum=38&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/sr-commodity-manager-eda-ip-at-western-digital-1445142177?refId=5367e09e-1bc6-48fe-962b-392fea47158c&position=18&pageNum=38&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/operations-strategy-analytics-manager-at-waymo-1483104129?refId=5367e09e-1bc6-48fe-962b-392fea47158c&position=19&pageNum=38&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/marketing-operations-manager-contractor-at-shutterfly-inc-1468927428?refId=5367e09e-1bc6-48fe-962b-392fea47158c&position=20&pageNum=38&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/software-engineering-manager-infradev-tools-at-linkedin-1270786472?refId=5367e09e-1bc6-48fe-962b-392fea47158c&position=21&pageNum=38&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/developer-relations-account-manager-cloud-at-nvidia-1460806063?refId=5367e09e-1bc6-48fe-962b-392fea47158c&position=22&pageNum=38&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/senior-manager-%E2%85%B0-programs-management-at-samsung-electronics-america-1506069582?refId=5367e09e-1bc6-48fe-962b-392fea47158c&position=23&pageNum=38&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/director-of-solution-delivery-at-stanford-university-graduate-school-of-business-1454428086?refId=5367e09e-1bc6-48fe-962b-392fea47158c&position=24&pageNum=38&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/front-of-house-operations-manager-at-flagship-facility-services-inc-1485186245?refId=5367e09e-1bc6-48fe-962b-392fea47158c&position=25&pageNum=38&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/office-manager-executive-assistant-human-resource-hr-at-cybercoders-1483787212?refId=2a403b09-a19b-401f-a6e2-114d4e549153&position=1&pageNum=39&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/manager-renewals-operations-at-pure-storage-1355366825?refId=2a403b09-a19b-401f-a6e2-114d4e549153&position=2&pageNum=39&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/sr-sales-operations-manager-sales-compensation-strategy-at-nutanix-1446178761?refId=2a403b09-a19b-401f-a6e2-114d4e549153&position=3&pageNum=39&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/fp-a-senior-manager-corporate-operations-at-intuitive-1483713728?refId=2a403b09-a19b-401f-a6e2-114d4e549153&position=4&pageNum=39&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/vp-global-regulatory-affairs-quality-assurance-at-align-technology-1404715290?refId=2a403b09-a19b-401f-a6e2-114d4e549153&position=5&pageNum=39&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/analytics-engineer-at-soundhound-inc-1486261238?refId=2a403b09-a19b-401f-a6e2-114d4e549153&position=6&pageNum=39&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/group-product-manager-growth-at-course-hero-1479987980?refId=2a403b09-a19b-401f-a6e2-114d4e549153&position=7&pageNum=39&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/sr-integrated-marketing-manager-at-vmware-1404198857?refId=2a403b09-a19b-401f-a6e2-114d4e549153&position=8&pageNum=39&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/senior-product-manager-at-intuit-1449518010?refId=2a403b09-a19b-401f-a6e2-114d4e549153&position=9&pageNum=39&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/vp-product-manager-at-itrenew-1454404243?refId=2a403b09-a19b-401f-a6e2-114d4e549153&position=10&pageNum=39&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/senior-program-manager-at-adobe-1483718567?refId=2a403b09-a19b-401f-a6e2-114d4e549153&position=11&pageNum=39&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/sr-internal-audit-manager-at-bloom-energy-1162848349?refId=2a403b09-a19b-401f-a6e2-114d4e549153&position=12&pageNum=39&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/quality-engineering-manager-pre-post-deployment-at-kespry-1424367418?refId=2a403b09-a19b-401f-a6e2-114d4e549153&position=13&pageNum=39&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/product-manager-at-supermicro-1463126211?refId=2a403b09-a19b-401f-a6e2-114d4e549153&position=14&pageNum=39&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/sr-community-manager-at-essex-corporation-1511892487?refId=2a403b09-a19b-401f-a6e2-114d4e549153&position=15&pageNum=39&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/program-operations-cloud-orchestration-manager-at-palo-alto-networks-1445145923?refId=2a403b09-a19b-401f-a6e2-114d4e549153&position=16&pageNum=39&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/marketing-technology-manager-at-demisto-1505241615?refId=2a403b09-a19b-401f-a6e2-114d4e549153&position=17&pageNum=39&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/program-manager-at-planet-interactive-1504465566?refId=2a403b09-a19b-401f-a6e2-114d4e549153&position=18&pageNum=39&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/human-resources-project-manager-at-8x8-1442534300?refId=2a403b09-a19b-401f-a6e2-114d4e549153&position=19&pageNum=39&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/product-manager-platform-at-confluent-1349602280?refId=2a403b09-a19b-401f-a6e2-114d4e549153&position=20&pageNum=39&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/product-manager-sr-staff-enterprise-data-center-at-juniper-networks-1397900788?refId=2a403b09-a19b-401f-a6e2-114d4e549153&position=21&pageNum=39&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/corporate-security-manager-at-automation-anywhere-1412938766?refId=2a403b09-a19b-401f-a6e2-114d4e549153&position=22&pageNum=39&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/business-continuity-program-manager-at-genomic-health-1463180665?refId=2a403b09-a19b-401f-a6e2-114d4e549153&position=23&pageNum=39&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/manager-product-design-at-earnin-1468960592?refId=2a403b09-a19b-401f-a6e2-114d4e549153&position=24&pageNum=39&trk=guest_job_search_job-result-card_result-card_full-click',
#   'https://www.linkedin.com/jobs/view/pricing-product-manager-at-netapp-1466674213?refId=2a403b09-a19b-401f-a6e2-114d4e549153&position=25&pageNum=39&trk=guest_job_search_job-result-card_result-card_full-click']}

# %%
glassdoor_time = glassdoor_end-glassdoor_start
linkedin_time = linkedin_end - linkedin_start
print('Glassdoor Link Mining Time: %.2f' % glassdoor_time)
print('LinkedIn Link Time: %.2f' % linkedin_time)
with open(job_links_glassdoor, 'wb') as f:
    pickle.dump(job_dict_glassdoor, f)
with open(job_links_linkedin, 'wb') as f:
    pickle.dump(job_dict_linkedin, f)
# Out:
# Glassdoor Link Mining Time: 546.35
# LinkedIn Link Time: 193.78

# %% [markdown]
# <a id='webscraping'></a>

# %% [markdown]
# ## 4. Webscraping the Job Descriptions

# %% [markdown]
# Now that we've gathered the job links, and saved them in a dictionary, we can now use `scrapy` to go through all these sites and then webscrape the relevant job data, including company size, location, industry, sector, location and job description.
#
# To make things simple, we'll run it as a script. This involves setting up a Twisted [reactor](https://twistedmatrix.com/documents/13.1.0/core/howto/reactor-basics.html) to allow for [asynchrony](https://en.wikipedia.org/wiki/Asynchrony_(computer_programming)) which makes it possible to scrape many sites quickly.

# %%
from twisted.internet import reactor
import scrapy
import logging
from scrapy.crawler import CrawlerRunner
from scrapy.utils.log import configure_logging
import pickle
from job_scraping_functions import GlassdoorDriver, LinkedInDriver
import re



class GlassdoorSpider(scrapy.Spider):

    name = "glassdoor"
    
    global output_job_data_glassdoor
    
    custom_settings = {
        'LOG_LEVEL': logging.WARNING,
        'FEED_FORMAT':'csv',                                 
        'FEED_URI': output_job_data_glassdoor                       
    }
    
    def start_requests(self):
        
        # this file should be changed to whatever dictionary was saved
        # from the previous search
        global job_links_glassdoor
        with open(job_links_glassdoor, 'rb') as f:
            location_urls = pickle.load(f)
        for location in location_urls:
            for url in location_urls[location]:
                yield scrapy.Request(url=url, callback=self.parse,
                                     cb_kwargs=dict(location=location))

    def parse(self, response, location):
        driver = GlassdoorDriver()
        driver.get(response.url)
        # Get job description
        job_container = driver.find_element_by_xpath(
            '//*[@id="JobDescriptionContainer"]')
        job_text = str(job_container.text)
        job_text = re.sub('\n', ' ', job_text)

        # Access company data on dynamic webpage via the Company tab
        tabs = driver.find_elements_by_class_name('link')
        for i in tabs:
            if re.search('Company', str(i.text)):
                i.click()
                break
        company_container = driver.find_element_by_xpath(
            '//*[@id="CompanyContainer"]')
        company_name_element = driver.find_element_by_xpath(
            '//*[@id="HeroHeaderModule"]/div[3]/div[1]/div[2]/span[2]')
        company_name = str(company_name_element.text)
        company_text = str(company_container.text)
        job_data = {'Location': location, 'Name': company_name, 'Description': job_text}
        driver.close()
        for i in ['Size', 'Industry', 'Sector']:
            job_data[i] = re.search(f'({i})(.*)(\n)', company_text).group(2)
        yield job_data

        
class LinkedinSpider(scrapy.Spider):

    name = "linkedin"
    
    global output_job_data_linkedin
    
    custom_settings = {
        'LOG_LEVEL': logging.WARNING,
        'FEED_FORMAT':'csv',                                 
        'FEED_URI': output_job_data_linkedin                       
    }
    
    def start_requests(self):        
        # this file should be changed to whatever dictionary was saved
        # from the previous search
        global job_links_linkedin
        with open(job_links_linkedin, 'rb') as f:
            location_urls = pickle.load(f)
        for location in location_urls:
            for url in location_urls[location]:
                yield scrapy.Request(url=url, callback=self.parse,
                                     cb_kwargs=dict(location=location))

    def parse(self, response, location):
        driver = LinkedinDriver()
        driver.get(response.url)
        # Get job description
        job_data = driver.get_job_data()
        yield job_data

# %%
configure_logging
runner = CrawlerRunner()

glassdoor_start = time.time()
runner.crawl(GlassdoorSpider)
glassdoor_end = time.time()

linkedin_start = time.time()
runner.crawl(LinkedinSpider)
linkedin_end = time.time()

d = runner.join()
d.addBoth(lambda _: reactor.stop())
reactor.run()

# %%
print('Glassdoor Job Scraping Time: %d' % (glassdoor_end-glassdoor_start))
print('LinkedIn Job Scraping Time: %d' % (linkedin_end-linkedin_start))
# Out:
# Glassdoor Job Scraping Time: 0
# LinkedIn Job Scraping Time: 0

# %% [markdown]
# <a id='analysis'></a>

# %% [markdown]
# ## 5. Analysis of Job Data

# %% [markdown]
# Now that we have the data, let's take a look at the fields we've scraped using `pandas`.

# %%
import pandas as pd
df_glassdoor = pd.read_csv(output_job_data_glassdoor)
df_linkedin = pd.read_csv(output_job_data_linkedin)

# %%
df_glassdoor.tail()

# %%
df_linkedin.tail()

# %% [markdown]
# <a id='functions'></a>

# %% [markdown]
# ### 5.1 Useful Functions

# %% [markdown]
# To better visualize and perform some natural language processing (NLP) analysis, we define some helper functions.

# %%
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from nltk.stem.wordnet import WordNetLemmatizer
import re
import nltk
from nltk.corpus import stopwords

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer


def normalize_text(df, stop_words):
    """
    Takes in a Pandas DataFrame object of text and returns a normalized
    corpus

    Parameters
    ---------------
   
    df : pandas DataFrame object
        The text column to process.
    stop_word : iterable
        Common English words to disregard in analysis
    
    Returns
    ----------------

    corpus : list of strings
        A list of text documents with the applied modifications
    
    """
    df.dropna()
    corpus = []
    lem = WordNetLemmatizer()
    word_count = df.apply(lambda x: len(str(x).split(" ")))
    num_words = word_count.count()
    for i in range(num_words):
        try:
            text = df[i]
            text = text.split()
            text = [lem.lemmatize(word.lower()) for word in text if not word in stop_words]
            text = " ".join(text)
            corpus.append(text)
        except:
            print(f'Trouble with row {i}')
            continue
    return corpus


def df_counts(df, category):
    """
    Creates a dataframe of counts for a specified 
    categorical variable

    Parameters
    ---------------
   
    df : pandas DataFrame object
        DataFrame object with categorical values of interest
    category : string
        String corresponding to a categorical column in the dataframe

    Returns
    ----------------

    df2 : pandas DataFrame object
        New dataframe with the counts of the categorical variable
    
    """ 
    df_grouped = (df
             .groupby(category)[category]
             .count()
             )
    
    d = {category: df_grouped.index.values, 'Count':df_grouped.values.flatten()}
    df2 = pd.DataFrame(d)
    return df2    
    
    
def flatten_groupby(df, cols, label):
    """
    Converts the multi-level dataframe from a multi-level groupby
    operation into a single level dataframe

    Parameters
    ---------------
   
    df : pandas DataFrame object
        The multi-level dataframe resulting from a groupby operation
    cols : string or list of strings
        The column(s) used for grouping in the order used for grouping
    label : string
        Name assigned to last column of dataframe, corresponding to the
        group operation ie. count, sum, mean etc.

    Returns
    ----------------

    df_flat_groupby : pandas DataFrame object        
        Flat hierarchy dataframe
        
    """
    
    cols_data = {}
    # Single groupby category case
    if type(df.index) is pd.core.indexes.base.Index:
        if type(cols) is list:
            category = cols[0]
        elif type(cols) is str:
            category = cols
        cols_data[category] = df.index.values
    
    # Multiple grouping case   
    elif type(df.index) is pd.core.indexes.multi.MultiIndex:
        for idx, category in enumerate(cols):
            cols_data[category] = [tup[idx] for tup in df.index.values]
    cols_data[label] = df.values.flatten()
    
    df_flat_groupby = pd.DataFrame(cols_data)
    
    return df_flat_groupby


def plot_word_cloud(corpus, stop_words,
    max_words=100,
    max_font_size=50,
    random_state=0, background_color='white'):
    """
    Creates and plots word cloud    

    Parameters
    ---------------
    corpus : iterable of text
        The collection of texts used to generate the wordcloud
    stop_word : iterable
        Common English words to disregard
    max_words : int
        Cutoff for the number of top frequent words to display.
    max_font_size : int
        Font size of the most frequent, and thus the largest, word
        
    """ 
    wordcloud = WordCloud( 
        background_color=background_color,
        stopwords=stop_words,
        max_words=max_words,
        max_font_size=max_font_size,
        random_state=random_state
        ).generate(str(corpus))
    print(wordcloud)
    fig = plt.figure(1)
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.show()
    
    
def get_top_N_grams(corpus, stop_words, ngram_range=(1,1), max_features=2000):
    """
    Get most frequently occuring words
    
    Parameters:
    ----------------
    corpus: list of words
        Text to analyze
    stop_word : iterable
        Common English words to disregard
    ngram_range : tuple (a,b)
        Range of N, [a,b], to consider for N-grams
    max_features: int or None
        Limit of top words to return
    N: int
        Defines the N-grams to examine
        
    Returns:    
    ----------------
    word_freq: list of strings
         description
    
    """
    vec = CountVectorizer(ngram_range=ngram_range, 
                          max_features=max_features,
                          token_pattern=r'(?u)\b\w+\b',
                          stop_words=stop_words).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_of_words = bag_of_words.sum(axis=0)
    words_freq = [(word, sum_of_words[0,idx]) for word, idx in vec.vocabulary_.items()]
    words_freq = sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:max_features]


def search_top_N_grams(corpus, stop_words, n_grams, max_features=2000):
    """
    Searches for the given N-grams' rank among the top frequent N-grams.    

    Parameters
    ---------------
   
    corpus : list of strings
        List of string documents
    stop_word : iterable
        Common English words to disregard
    n_gram : list of strings
        The N-grams to search for, must be the same size
    max_features : int
        The cutoff for how many top N-grams to show

    Returns
    ----------------

    sorted_df : DataFrame object 
        Pandas dataframe with columns N-gram, Count, and Rank with words ordered
        by rank in ascending order
       
    """
    counts = [None for i in n_grams]
    rankings = counts[:]
    
    n_grams_lowercase = [i.lower() for i in n_grams]
    N_ = [len(i.split()) for i in n_grams]
    N_max = max(N_)
    topn = get_top_N_grams(corpus, stop_words, ngram_range=(1,N_max), max_features=max_features)
    
    for top_n_gram,count in topn:
        if top_n_gram in n_grams_lowercase:
            idx = n_grams_lowercase.index(top_n_gram)
            rankings[idx]= topn.index((top_n_gram, count))+1
            counts[idx] = count
            
    d = {'N-gram': n_grams, 'Count':counts, 'Ranking':rankings}
    df = pd.DataFrame(d)       
    sorted_df = df.sort_values('Ranking', ascending=True).reset_index(drop=True)
    return sorted_df

def bar_plot(df,x,y,title=None,figsize=(13,8), rotation=75,
             xtickfont=12, xlabelfont=16, ylabelfont=16,
             titlefont=25, context='poster', ci=None):
    """
    Wrapper function for a barplot with seaborn

    Parameters
    ---------------
   
    df : pandas DataFrame object
        Dataframe containing the data to plot
    x : string
        Column in dataframe containing x values
    y : string
        Column in dataframe containing y values
    title : string
        Title of the chart
    figsize : tuple of numbers
        Dimensions of chart
    rotation : int
        Degree of rotation for xtick labels
    xtickfont : int
        Fontsize for xtick labels
    context : string
        Specific seaborn context keywords ie 'talk','poster','figure'
        'notebook', 'paper'
    ci : float or None
        Confidence interval bar width
    """ 

    sns.set(rc={'figure.figsize':figsize})    
    g = sns.barplot(x=df[x], y=df[y],data=df,ci=ci)
    g.set_xticklabels(df[x], rotation=75, fontdict={'fontsize':xtickfont})
    g.set_xlabel(xlabel=x,fontdict={'fontsize':xlabelfont})
    g.set_ylabel(ylabel=y,fontdict={'fontsize':ylabelfont})
    
    g.set_title(title, fontdict={'fontsize':titlefont});
    sns.set(context=context)


def plot_N_gram_counts(corpus, stop_words, n_grams, title, rotation=75, max_features=2000):
    """
    Plot the word counts of the specified N-grams if they are found among the
    top corpus.    

    Parameters
    ---------------
   
    corpus : list of strings
        List of string documents
    stop_word : iterable
        Common English words to disregard
    n_grams : list of strings
        The N-grams to search for, must be the same size
    rotation : int
        Degrees to rotate the x-axis tick labels by 
    max_features : int
        The cutoff for how many top N-grams to consider
    title : string
        Title to give the plot, rational for the chosen words

    Returns
    ----------------

    sorted_df : DataFrame object 
        Pandas dataframe with columns N-gram, Count, and Rank with words ordered
        by rank in ascending order.
       
    """
    
    df = search_top_N_grams(corpus, stop_words, n_grams, max_features)
    x = 'N-gram'
    y = 'Count'
    
    bar_plot(df, x, y, title=title, rotation=rotation)    
    
def plot_top_N_grams(corpus, stop_words, max_features=10, ngram_range=(1,1), rotation=75):
    """
    Plots a bar chart of the most frequently occuring words
    
    Parameters:
    ----------------
    corpus: list of text
        Text to analyze
    stop_word : iterable
        Common English words to disregard
    max_features: int or None
        Limit of top words to return
    ngram_range: tuple
        Defines the N-grams to examine
        
    """
    top_words = get_top_N_grams(corpus, stop_words, max_features=max_features, ngram_range=ngram_range)
    top_df = pd.DataFrame(top_words)
    top_df.columns=["N-grams", "Freq"]
    
    #Barplot of most freq words
    
    context='talk'
    x="N-grams"
    y="Freq"   
    title =f'Top {max_features} {ngram_range}-grams'
    bar_plot(top_df, x, y, title=title,)
    
def create_tfidf_vector(text, corpus, stop_words, max_features=10000, ngram_range=(1,3)):
    """
    Convert text to a term-frequency inverse document frequency vector
    based on a fitted corpus and include feature names  

    Parameters
    ---------------
   
    text : string
        Job description to convert to a ti-fidf word vector         
    corpus : list of strings        
        Text to analyze, the documents from which inverse document frequency is
        calculated
    stop_words : list of strings
        Words to ignore in analysis due to being common or insignificant 
    max_features : int
        Cutoff for the number of words to consider
    ngram_range : tuple of ints
        Min and max n-gram sizes to consider

    Returns
    ----------------

    tifidf_vector : scipy sparse matrix object
        Vector object of tf-idf scores whose indices correspond to words
    feature_names : array
        Array of vocabulary words at the indices of the tfidf_vector
    
    """
    TV = TfidfVectorizer(max_df=.8, stop_words=stop_words,
                    max_features=10000, ngram_range=(1,3),
                    smooth_idf=True, use_idf=True,
                    min_df=1)
    TV.fit(corpus)
    tfidf_vector = TV.transform([text])
    feature_names = TV.get_feature_names()
    
    return tfidf_vector, feature_names


        
def sort_tfidf_vector(tf_idf_vector):
    """
    Sorts tf-idf vector in descending order
    
    Parameters:
    ----------------
    tif_idf_vector: scipy.sparse.csr_matrix object
        Compressed Sparse Row (row, column, data) representation of a sparse matrix            
    
    Returns:    
    ----------------
    sorted_tups: list of tuples
         Sorted tuples of tf-idf scores and corresponding feature indices
    
    """ 
    tuples = zip(tf_idf_vector.data, tf_idf_vector.indices)
    return sorted(tuples, key=lambda x: (x[0],x[1]), reverse=True)

def extract_topn_from_vector(feature_names, tf_idf_vector, topn=10):
    """
    Get top n features ordered by tf-idf
    
    Parameters:
    ----------------
    feature_names: list
        List of column features, ie n-grams
    tif_idf_vector: scipy.sparse.csr_matrix object
        Compressed Sparse Row (row, column, data) representation of a sparse matrix            
    topn: int
        Cutoff of top-n list
        
    Returns:    
    ----------------
    keywords_scores: pandas DataFrame object
        DataFrame of keywords and td-idf scores in order of descending scores
    
    """
    sorted_items = sort_tfidf_vector(tf_idf_vector)
    keywords = []
    scores = []
    d = {feature_names[idx]:round(score,3) for score,idx in sorted_items[:topn]}
    return pd.DataFrame(d.items(),columns=['Keyword', 'tf-idf Score'])

# %% [markdown]
# <a id='sector_size'></a>

# %% [markdown]
# ### 5.2 Jobs by Sector and Size

# %% [markdown]
# #### Overall

# %% [markdown]
# How many different sectors of the economy is our job title found in?

# %%
# Create a column of sector counts
category = 'Sector'
df_sector_counts = df_counts(df, category)
len(df['Sector'].unique())

# %% [markdown]
# Which sectors have the most openings?

# %%
df_sector_counts.sort_values('Count', ascending=False).reset_index(drop=True)

# %% [markdown]
# Here we group the job openings by location and economic sector:

# %%
cols = ['Location','Sector']
df_sector2 = (df
                 .groupby(cols)[cols[-1]]
                 .count()
                )

df_location_sectorcounts = flatten_groupby(df=df_sector2,cols=cols,label='Count')
df_location_sectorcounts

# %% [markdown]
# Here are visualizations of these numbers:

# %%
plot_args = {'df':df_sector_counts, 'x':'Sector','y':'Count',
             'title': 'Jobs by Sector', 'ci':None}
bar_plot(**plot_args)

# %% [markdown]
# #### Specific Locations

# %% [markdown]
# The spread of jobs might be significantly different depending on locations, so it might be worth looking at the differences to consider which locations to focus on. In the following script, feel free to change the variable `city` to whatever you'd like in the proper format.

# %%
# repeat plot above but passing it to seaborn filtering by location
city = 'San Jose, CA (US)'
df_city = df_location_sectorcounts[df_location_sectorcounts['Location']==city]
plot_args = {'df':df_city, 'x':'Sector','y':'Count',
             'title': f'Jobs by Sector: {city}', 'ci':None}
bar_plot(**plot_args)

# %%
city = 'San Francisco, CA (US)'
df_city = df_location_sectorcounts[df_location_sectorcounts['Location']==city]
plot_args = {'df':df_city, 'x':'Sector','y':'Count',
             'title': f'Jobs by Sector: {city}', 'ci':None}
bar_plot(**plot_args)

# %% [markdown]
# <a id='job_descriptions'></a>

# %% [markdown]
# ### 5.3 Analysis of Job Descriptions

# %% [markdown]
# #### Creating a Corpus of Text
#
# Below we define *stop words* which we ignore because they are in the background so often. When using your own dataset, you should iteratively add stop words that you don't want to see. We're going to use the full list of job descriptions as our **corpus** of words to analyze.

# %%
nltk.download('stopwords')
nltk.download('wordnet')
stop_words = set(stopwords.words("english"))
##Creating a list of custom stopwords
new_words = ['sexual', 'orientation', 'equal', 'opportunity', 'race', 'color',
            'gender', 'identity', 'regard', 'religion', 'veteran', 'status', 'protected', 'we', 'the', 'you',
            'sex', 'national', 'origin']
stop_words = stop_words.union(new_words)

corpus = normalize_text(df['Description'],stop_words=stop_words)

# %%
# number of stop words we'll exclude
len(stop_words)

# %%
# the number of job descriptions
len(corpus)

# %% [markdown]
# #### Wordcounts

# %% [markdown]
# Here's a quick graphic to look at the top n-grams based on size of the font. Notice any words that don't seem interesting? You can always add them to the stop words list previously defined so more meaningful words can be emphasized.

# %%
plot_word_cloud(corpus, stop_words)

# %% [markdown]
# #### Top N-grams

# %% [markdown]
# The actual n-gram counts that were used to create the previous visualization can be seen below. We can see the words that pop up the most in job descriptions:

# %%
topn = get_top_N_grams(corpus, stop_words, ngram_range=(1,1), max_features=100000)
topn

# %% [markdown]
# #### Searching for N-gram Ranking

# %% [markdown]
# However, what if we wanted to look at the relative frequencies of words of our own choice? We can accomplish that by searching the above list with the following code along with a list of words we define and come up with a "top skills" list ourselves:

# %%
# Feel free to replace this list with words of your choice
n_grams = ['Python','R','SAS','Stata','Java','C','Javascript', 'Excel', 'Power Point', 'Tableau', 'Word', 'html']

skill_rankings = search_top_N_grams(corpus, stop_words, n_grams, max_features=1000000)

skill_rankings

# %% [markdown]
# #### Plotting the Top N-grams

# %% [markdown]
# We can visualize the above numbers in a bar graph:

# %%
plot_top_N_grams(corpus, stop_words, ngram_range=(1,3), max_features=20)

# %% [markdown]
# <a id='tfidf'></a>

# %% [markdown]
# ### 5.4 Term Frequency - Inverse Document Frequency

# %% [markdown]
# In some cases, we may wish to convert the raw word counts previously produced to a normalized metric which favors words that biases words that appear frequently in a document but penalizes words that frequently occur in the background corpus. This is the [term frequency–inverse document frequency](https://en.wikipedia.org/wiki/Tf%E2%80%93idf).
#
# **Term Frequency**
#
# $$ tf(t,d) = \text{raw count}$$
#
# where $t$ is the term and $d$ is the document.
#
# **Inverse Document Frequency**
#
# $$ idf(t) = \log\Big(\frac{n}{df(t)+1}\Big)$$
#
# where $df(t)$ is the document frequency, the number of documents containing term $t$ and $n$ is the number of documents in the corpus.
#
# **Term Frequency - Inverse Document Frequency**
#
# $$ td-idf = tf(t,d)*idf(t)$$

# %% [markdown]
# <a id='keywords'></a>

# %% [markdown]
# ### 5.5 Extracting the Top Keywords from a Jobs Description

# %% [markdown]
# What if we were looking at a job description and wanted to focus on words unique to that one as opposed to being found commonly in other descriptions? We could then use the tf-idf metric to find *keywords* of the job description of interest.
#
# To do this we first choose a job description to convert. For example, we can choose one from the job descriptions we scraped in our corpus:

# %%
corpus[100]

# %% [markdown]
# Now we take this text and feed it into a few functions that turn the description into a word vector that contains tf-idf scores.

# %%
text = corpus[100]
tfidf_vector, feature_names = create_tfidf_vector(text, corpus, stop_words, ngram_range=(1,4))
extract_topn_from_vector(feature_names, tfidf_vector, topn=40)
